# %%
from datetime import *
from tkinter import *
from tkinter import ttk
from datetime import datetime
import random
import tkinter.messagebox

class Library:
    def __init__(self,root):
        self.root = root  
        self.root.title('library management system')
        self.root.geometry('1350x750+0+0')
        self.root.configure(background='cyan')
        
        #=========define variable=============================#
        MType = StringVar()
        Ref = StringVar()
        Title = StringVar()
        FirstName = StringVar()
        Surname = StringVar()
        Address1 = StringVar()
        Address2 = StringVar()
        PostCode = StringVar()
        MobileNo = StringVar()
        BookId = StringVar()
        BookTitle = StringVar()
        BookType = StringVar()
        Author = StringVar()
        DateBorrowed = StringVar()
        DateDue = StringVar()
        SellingPrice = StringVar()
        LateReturnFine = StringVar()
        DateOverDue = StringVar()
        DayOnLoan = StringVar()
        Prescreption = StringVar()
        
        def iReset():
            MType.set('')
            Ref.set('')
            Title.set('')
            FirstName.set('')
            Surname.set('')
            Address1.set('')
            Address2.set('')
            PostCode.set('')
            MobileNo.set('')
            BookId.set('')
            BookTitle.set('')
            BookType.set('')
            Author.set('')
            DateBorrowed.set('')
            DateDue.set('')
            SellingPrice.set('')
            LateReturnFine.set('')
            DateOverDue.set('')
            DayOnLoan.set('')

        def iDelete():
            iReset()
            self.txtDisplayR.delete('1.0',END) # neeche wala text
            self.txtDisplayR1.delete('1.0',END)
        def iExit():
            iExit = tkinter.messagebox.askyesno ('Library management system','confirm if you want to exit')
            if iExit > 0:
                root.destroy()
                return
        def iDisplayData():
            self.txtDisplayR1.insert(END,'\t'+MType.get()+'\t\t'+Ref.get()+'\t'+Title.get()+'\t'+FirstName.get()+
                                   '\t'+Surname.get()+'\t\t'+Address1.get()+'\t\t'+Address2.get()+'\t'+
                                   PostCode.get()+'\t'+BookTitle.get()+'\t\t'+DateBorrowed.get()+'\t\t'+DayOnLoan.get() + '\n')
        def iReciept():
            self.txtDisplayR.insert(END,'Member Type:\t\t'+ MType.get()+'\n')
            self.txtDisplayR.insert(END,'Ref No:\t\t'+Ref.get()+'\n')
            self.txtDisplayR.insert(END,'Title:\t\t'+Title.get()+'\n')
            self.txtDisplayR.insert(END,'First Name:\t\t'+FirstName.get()+'\n')
            self.txtDisplayR.insert(END,'Surname:\t\t'+Surname.get()+'\n')
            self.txtDisplayR.insert(END,'Address1:\t\t'+Address1.get()+'\n')
            self.txtDisplayR.insert(END,'Address2:\t\t'+Address2.get()+'\n')
            self.txtDisplayR.insert(END,'PostCode:\t\t'+PostCode.get()+'\n')
            self.txtDisplayR.insert(END,'BookId:\t\t'+BookId.get()+'\n')
            self.txtDisplayR.insert(END,'BookTitle:\t\t'+BookTitle.get()+'\n')
            self.txtDisplayR.insert(END,'Author:\t\t'+Author.get()+'\n')
            self.txtDisplayR.insert(END,'Date Borrowed:\t\t'+DateBorrowed.get()+'\n')
        # =====================Frame======================
        MainFrame = Frame(self.root)
        MainFrame.grid()
        # put title frame inside mainframe
        
        TitleFrame = Frame(MainFrame,width=1350,padx=20,relief=RIDGE)
        TitleFrame.pack(side=TOP)
        
        self.lblTitle = Label(TitleFrame,width=39,font=('arial',40,'bold'),text='\tLibrary Management System\t',padx=12)
        self.lblTitle.grid()
        
        ButtonFrame = Frame(MainFrame,bd=10,width = 1350,height=50,padx=20,relief=RIDGE)
        ButtonFrame.pack(side=BOTTOM)
        
        FrameDetail = Frame(MainFrame,bd=10,width = 1350,height=100,padx=20,relief=RIDGE)
        FrameDetail.pack(side=BOTTOM)
        
        DataFrame = Frame(MainFrame,bd=10,width = 1300,height=400,padx=20,relief=RIDGE)
        DataFrame.pack(side=BOTTOM)
        
        DataFrameLeft = LabelFrame(DataFrame,bd=10,width = 800,height=300,padx=20,relief=RIDGE,font=('arial',12,'bold'),text='Library management info')
        DataFrameLeft.pack(side=LEFT)
        
        DataFrameRight = LabelFrame(DataFrame,bd=10,width = 450,height=300,padx=20,relief=RIDGE,font=('arial',12,'bold'),text='Book Details')
        DataFrameRight.pack(side=LEFT)
        
        
        #====================================widgets====================================
        self.lblMemberType = Label(DataFrameLeft,font=('arial',12,'bold'),text='Member type:',padx=2,pady=2)
        self.lblMemberType.grid(row=0,column=0,sticky=W)
        
        self.cboMemberType = ttk.Combobox(DataFrameLeft,font=('arial',12,'bold'),state='readonly',textvariable=MType,width=23)
        self.cboMemberType['value'] = ('','Student','Lecturer','Admin staff')
        self.cboMemberType.current(0)
        self.cboMemberType.grid(row=0,column=1)
        
        self.lblBookId = Label(DataFrameLeft,font=('arial',12,'bold'),text='Book Id:',padx=2,pady=2)
        self.lblBookId.grid(row=0,column=2,sticky=W)
        self.lblBookId = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=BookId,width = 25)
        self.lblBookId.grid(row=0,column=3,sticky=W)
        
        self.lblRef = Label(DataFrameLeft,font=('arial',12,'bold'),text='Reference No:',padx=2,pady=2)
        self.lblRef.grid(row=1,column=0,sticky=W)
        self.txtRef = Entry(DataFrameLeft,font=('arial',12,'bold'),width = 25,textvariable=Ref)
        self.txtRef.grid(row=1,column=1)
        
        
        self.lblBookTitle = Label(DataFrameLeft,font=('arial',12,'bold'),text='Book Title:',padx=2,pady=2)
        self.lblBookTitle.grid(row=1,column=2,sticky=W)
        self.txtBookTitle = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=BookTitle,width = 25)
        self.txtBookTitle.grid(row=1,column=3,sticky=W)
        
        self.lblTitle = Label(DataFrameLeft,font=('arial',12,'bold'),text='Title:',padx=2,pady=2)
        self.lblTitle.grid(row=2,column=0,sticky=W)
        
        self.cboTtile = ttk.Combobox(DataFrameLeft,font=('arial',12,'bold'),textvariable=Title,state='readonly',width=23)
        self.cboTtile['value'] = ('','Mr.','Miss','Dr','Capt.','Ms')
        self.cboTtile.current(0)
        self.cboTtile.grid(row=2,column=1)
        
        self.lblAuthor = Label(DataFrameLeft,font=('arial',12,'bold'),text='Author:',padx=2,pady=2)
        self.lblAuthor.grid(row=2,column=2,sticky=W)
        self.txtAuthor = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=Author,width = 25)
        self.txtAuthor.grid(row=2,column=3,sticky=W)
        
        self.lblFirstName = Label(DataFrameLeft,font=('arial',12,'bold'),text='FirstName:',padx=2,pady=2)
        self.lblFirstName.grid(row=3,column=0,sticky=W)
        self.txtFirstName = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=FirstName,width = 25)
        self.txtFirstName.grid(row=3,column=1,sticky=W)
        
        self.lblDateBorrowed = Label(DataFrameLeft,font=('arial',12,'bold'),text='Date Borrowed:',padx=2,pady=2)
        self.lblDateBorrowed.grid(row=3,column=2,sticky=W)
        self.txtDateBorrowed = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=DateBorrowed,width = 25)
        self.txtDateBorrowed.grid(row=3,column=3,sticky=W)
        
        self.lblSurname = Label(DataFrameLeft,font=('arial',12,'bold'),text='Surname:',padx=2,pady=2)
        self.lblSurname.grid(row=4,column=0,sticky=W)
        self.txtSurname = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=Surname,width = 25)
        self.txtSurname.grid(row=4,column=1,sticky=W)
        
        self.lblDateDue = Label(DataFrameLeft,font=('arial',12,'bold'),text='DateDue:',padx=2,pady=2)
        self.lblDateDue.grid(row=4,column=2,sticky=W)
        self.txtDateDue = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=DateDue,width = 25)
        self.txtDateDue.grid(row=4,column=3,sticky=W)
        
        self.lblAddres1 = Label(DataFrameLeft,font=('arial',12,'bold'),text='Addres1:',padx=2,pady=2)
        self.lblAddres1.grid(row=5,column=0,sticky=W)
        self.txtAddres1 = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=Address1,width = 25)
        self.txtAddres1.grid(row=5,column=1,sticky=W)
        
        self.lblDaysOnLoan = Label(DataFrameLeft,font=('arial',12,'bold'),text='DaysOnLoan:',padx=2,pady=2)
        self.lblDaysOnLoan.grid(row=5,column=2,sticky=W)
        self.txtDaysOnLoan = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=DayOnLoan,width = 25)
        self.txtDaysOnLoan.grid(row=5,column=3,sticky=W)
        
        self.lblAddres2 = Label(DataFrameLeft,font=('arial',12,'bold'),text='Addres2:',padx=2,pady=2)
        self.lblAddres2.grid(row=6,column=0,sticky=W)
        self.txtAddres2 = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=Address2,width = 25)
        self.txtAddres2.grid(row=6,column=1,sticky=W)
        
        
        self.lblLateReturnFine = Label(DataFrameLeft,font=('arial',12,'bold'),text='LateReturnFine:',padx=2,pady=2)
        self.lblLateReturnFine.grid(row=6,column=2,sticky=W)
        self.txtLateReturnFine = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=LateReturnFine,width = 25)
        self.txtLateReturnFine.grid(row=6,column=3,sticky=W)
        
        self.lblPostCode = Label(DataFrameLeft,font=('arial',12,'bold'),text='PostCode:',padx=2,pady=2)
        self.lblPostCode.grid(row=7,column=0,sticky=W)
        self.txtPostCode = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable= PostCode,width = 25)
        self.txtPostCode.grid(row=7,column=1,sticky=W)
        
        
        self.lblDateOverDue = Label(DataFrameLeft,font=('arial',12,'bold'),text='Date Over Due:',padx=2,pady=2)
        self.lblDateOverDue.grid(row=7,column=2,sticky=W)
        self.txtDateOverDue = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable=  DateOverDue,width = 25)
        self.txtDateOverDue.grid(row=7,column=3,sticky=W)
        
        self.lblMobileNo = Label(DataFrameLeft,font=('arial',12,'bold'),text='MobileNo:',padx=2,pady=2)
        self.lblMobileNo.grid(row=8,column=0,sticky=W)
        self.txtMobileNo = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable= MobileNo,width = 25)
        self.txtMobileNo.grid(row=8,column=1,sticky=W)
        
        self.lblSellingPrice = Label(DataFrameLeft,font=('arial',12,'bold'),text='SellingPrice:',padx=2,pady=2)
        self.lblSellingPrice.grid(row=8,column=2,sticky=W)
        self.txtSellingPrice = Entry(DataFrameLeft,font=('arial',12,'bold'),textvariable= SellingPrice,width = 25)
        self.txtSellingPrice.grid(row=8,column=3,sticky=W)
           #===========================widgets==================================================#
        
        self.txtDisplayR = Text(DataFrameRight,font=('arial',12,'bold'),width = 32,height=13,padx=8,pady=20)
        self.txtDisplayR.grid(row=0,column=2)
        #==========================listbox============================================================#
        scrollbar = Scrollbar(DataFrameRight)
        scrollbar.grid(row=0,column=1,sticky='ns')
        
        ListOfBooks = ['Cinderella','Game Design','Ancient Rome','Made in Africa','Sleeping Beauty','London',
                      'Neigeria','Snow white','Shriek 3','London Street','I love lagos','love kenya','Hello India']
        def SelectedBook(evt):
            value = str(booklist.get(booklist.curselection()))
            w = value
            if (w == 'Cinderella'):
                BookId.set('ISBN 549530583851')
                BookTitle.set('the great')
                Author.set('Paul Parker')
                
           
                SellingPrice.set('400')
                iReciept()
                
                import datetime
                d1 = date(2019,10,25)
                d2 = date(2019,11,10)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))
            
            elif (w == 'Game Design'):
                BookId.set('ISBN 549530583852')
                BookTitle.set('designer at best')
                Author.set('herman zose')
                
                SellingPrice.set('700')
                iReciept()
                
                import datetime
                d1 = date(2019,10,25)
                d2 = date(2019,11,27)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))
               
            elif (w == 'Ancient Rome'):
                BookId.set('ISBN 549530583853')
                BookTitle.set('Historical')
                Author.set('Alwardo Gucci')
                
                SellingPrice.set('900')
                iReciept()
                
                import datetime
                d1 = date(2019,9,25)
                d2 = date(2019,10,27)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))
            elif (w == 'Made in Africa'):
                BookId.set('ISBN 549530583854')
                BookTitle.set('the great')
                Author.set('Paul Parker')
                
           
                SellingPrice.set('400')
                iReciept()
                
                import datetime
                d1 = date(2019,10,25)
                d2 = date(2019,11,10)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))                      
            elif (w == 'Sleeping Beauty'):
                BookId.set('ISBN 549530583855')
                BookTitle.set('designer at best')
                Author.set('herman zose')
                
                SellingPrice.set('700')
                iReciept()
                
                import datetime
                d1 = date(2019,10,25)
                d2 = date(2019,11,27)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))
            elif (w == 'London'):
                BookId.set('ISBN 549530583856')
                BookTitle.set('Historical')
                Author.set('Alwardo Gucci')
                
                SellingPrice.set('900')
                iReciept()
                
                import datetime
                d1 = date(2019,9,25)
                d2 = date(2019,10,27)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))
            elif (w == 'Neigeria'):
                BookId.set('ISBN 549530583857')
                BookTitle.set('Geography')
                Author.set('chandrashekhar')
                
                SellingPrice.set('700')
                iReciept()
                
                import datetime
                d1 = date(2019,9,12)
                d2 = date(2019,12,22)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))
            elif (w == 'Snow white'):
                BookId.set('ISBN 549530583858')
                BookTitle.set('Entertaining')
                Author.set('Stewartt john')
                
                SellingPrice.set('1000')
                iReciept()
                
                import datetime
                d1 = date(2019,11,12)
                d2 = date(2019,12,29)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))
            elif (w == 'Shriek 3'):
                BookId.set('ISBN 549530583859')
                BookTitle.set('Entertaining')
                Author.set('nelasa hudson')
                
                SellingPrice.set('1200')
                iReciept()
                
                import datetime
                d1 = date(2019,6,12)
                d2 = date(2019,9,29)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))
            elif (w == 'London Street'):
                BookId.set('ISBN 549530583860')
                BookTitle.set('Mapping')
                Author.set('David can')
                
                SellingPrice.set('1200')
                iReciept()
                
                import datetime
                d1 = date(2019,7,12)
                d2 = date(2019,9,29)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))
            elif (w == 'Hello India'):
                BookId.set('ISBN 549530583861')
                BookTitle.set('the great')
                Author.set('Dr.Abdul Kalam')
                
                SellingPrice.set('1800')
                iReciept()
                
                import datetime
                d1 = date(2019,10,12)
                d2 = date(2019,11,1)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))
            elif (w == 'I love lagos'):
                BookId.set('ISBN 549530583862')
                BookId.set('ISBN 549530583856')
                BookTitle.set('Historical')
                Author.set('Alwardo Gucci')
                
                SellingPrice.set('900')
                iReciept()
                
                import datetime
                d1 = date(2019,9,25)
                d2 = date(2019,10,27)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))               
            elif (w == 'love kenya'):
                BookId.set('ISBN 549530583863')
                BookId.set('ISBN 549530583856')
                BookTitle.set('Historical')
                Author.set('Alwardo Gucci')
                
                SellingPrice.set('900')
                iReciept()
                
                import datetime
                d1 = date(2019,9,25)
                d2 = date(2019,10,27)
                d3 = datetime.date.today()
                delta = (d2-d1)
                DateBorrowed.set(d1)
                DateDue.set(d2)
                fine = 0
                over = 'No'
                if d3 > d2:
                    fine = ((d3-d2).days)*10
                    over = 'yes'
                DayOnLoan.set(delta.days)
                DateOverDue.set(over)
                LateReturnFine.set(str(fine))        
        booklist = Listbox(DataFrameRight,width=20,height=12,font=('arial',12,'bold'))
        booklist.bind('<<ListboxSelect>>',SelectedBook)
        booklist.grid(row=0,column=0,padx=8)
        scrollbar.config(command=booklist.yview)
        for items in ListOfBooks:
            booklist.insert(END,items)
        #====================label===========================================================#
        self.lblLabel = Label(FrameDetail,font=('arial',10,'bold'),pady=8,text=
                             'Member type\t Referece no\t Title\t Firstname\t Surname\t address 1\t address2\t Post code\t Book title\t Date Borrowed\t Day on loan')
        self.lblLabel.grid(row=0,column=0)
        self.txtDisplayR1 = Text(FrameDetail,font=('arial',12,'bold'),width = 150,height=4,padx = 2,pady=4)
        self.txtDisplayR1.grid(row=1,column=0)
        #===========================button==================================================#
        
        self.btnDisplayData=Button(ButtonFrame,text='Display Data',font=('arial',12,'bold'),width=30,bd=4,command=iDisplayData)
        self.btnDisplayData.grid(row=0,column=0)
        
        self.btnDelete=Button(ButtonFrame,text='Delete',font=('arial',12,'bold'),width=30,bd=4,command=iDelete)
        self.btnDelete.grid(row=0,column=1)
        
        self.btnReset=Button(ButtonFrame,text='Reset',font=('arial',12,'bold'),width=30,bd=4,command=iReset)
        self.btnReset.grid(row=0,column=2)
        
        self.btnExit=Button(ButtonFrame,text='EXIT',font=('arial',12,'bold'),width=30,bd=4,command=iExit)
        self.btnExit.grid(row=0,column=3)
    

        
        
        
        
if __name__=='__main__':
    root = Tk()
    applcation = Library(root)
    root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\anaconda\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-126-f26e58052ebf>", line 221, in SelectedBook
#     value = str(booklist.get(booklist.curselection()))
#   File "D:\anaconda\lib\tkinter\__init__.py", line 2798, in get
#     return self.tk.call(self._w, 'get', first)
# _tkinter.TclError: bad listbox index "": must be active, anchor, end, @x,y, or a number
